# %%
import os

import numpy as np
import spacy

from spacy import displacy

from scripts.jsonl import read_jsonl

# %%
MODEL_PATH = "training/spancat/model-best"

DATA_PATH = "../../data/"
TEST_DATA = os.path.join(DATA_PATH, "jsonl/test.jsonl")

# %%
test_data = list(read_jsonl(TEST_DATA))

# %%
nlp = spacy.load(MODEL_PATH)

# %%
def spancat_visualize(nlp: spacy.language.Language, text: str):
    """Visualize the named entities in the text using the spancat model"""
    doc = nlp(text)

    spans = []
    for span in doc.spans["sc"]:
        spans.append(
            {"start_token": span.start, "end_token": span.end, "label": span.label_}
        )

    data = {
        "text": text,
        "spans": spans,
        "tokens": [token.text for token in doc],
    }

    displacy.render(data, style="span", manual=True)

# %%
example = np.random.choice(test_data)
spancat_visualize(nlp, example["sentences"])
# Out:
# <span class="tex2jax_ignore"><div class="spans" style="line-height: 2.5; direction: ltr">Акция протеста на Майдане Независимости объявлена
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     бессрочной
#
# <span style="background: #ffeb80; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ffeb80; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ffeb80; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         EVENT
#     </span>
# </span>
#
#
# </span>
#
#
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     Один
#
# ...
